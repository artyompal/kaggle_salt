# %%
import os
import sys
import random
import gc
import pickle

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers
from keras.callbacks import Callback
import keras.backend as K
import numpy as np

import imgaug as ia
from imgaug import augmenters as iaa

import tensorflow as tf
from tta_wrapper import tta_segmentation

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img
import imgaug
import time
t_start = time.time()
# Out:
# Using TensorFlow backend.

# %%
VERSION = 32
SEED = 42
FOLDS = 5
DEPTH = True
basic_name = f'Unet_resnet_v{VERSION}'
save_model_name = basic_name + '.model'
save_model_name_lov = basic_name + '_lov.model'
submission_file = basic_name + '.csv'
imgaug.seed(SEED)

print(save_model_name)
print(save_model_name_lov)
print(submission_file)
# Out:
# Unet_resnet_v31.model
# Unet_resnet_v31_lov.model
# Unet_resnet_v31.csv

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %%
# Loading of training/testing ids and depths
train_df = pd.read_csv("../data/raw/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../data/raw/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

len(train_df)
# Out:
# 4000

# %%
train_df["images"] = [np.array(load_img("../data/raw/train/images/{}.png".format(idx),
                                        color_mode = "grayscale",)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df["masks"] = [np.array(load_img("../data/raw/train/masks/{}.png".format(idx),
                                       color_mode = "grayscale",)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
SUBSET = len(train_df)
train_df = train_df.head(SUBSET)
len(train_df)
# Out:
# 4000

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
# Build model
def build_model(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        #loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        loss = tf.tensordot(tf.nn.elu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
def predict_result(model,x_test,img_size_target): # predict both orginal and reflect x
    x_test_reflect =  np.array([np.fliplr(x) for x in x_test])
    preds_test = model.predict(x_test).reshape(-1, img_size_target, img_size_target)
    preds_test2_refect = model.predict(x_test_reflect).reshape(-1, img_size_target, img_size_target)
    preds_test += np.array([ np.fliplr(x) for x in preds_test2_refect] )
    return preds_test/2

# %%
def add_depth_coord(images):
    """ Takes dataset (N, W, H, 1) returns (N, W, H, 3). """
    if not DEPTH:
        return images
    assert(len(images.shape) == 4)
    channel1 = np.zeros_like(images)

    h = images.shape[1]
    for row, const in enumerate(np.linspace(0, 1, h)):
        channel1[:, row, ...] = const

    channel2 = images * channel1
    images = np.concatenate([images, channel1, channel2], axis=-1)
    return images

class SGDRScheduler(Callback):
    '''Cosine annealing learning rate scheduler with periodic restarts.
    # Usage
        ```python
            schedule = SGDRScheduler(min_lr=1e-5,
                                     max_lr=1e-2,
                                     steps_per_epoch=np.ceil(epoch_size/batch_size),
                                     lr_decay=0.9,
                                     cycle_length=5,
                                     mult_factor=1.5)
            model.fit(X_train, Y_train, epochs=100, callbacks=[schedule])
        ```
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        lr_decay: Reduce the max_lr after the completion of each cycle.
                  Ex. To reduce the max_lr by 20% after each cycle, set this value to 0.8.
        cycle_length: Initial number of epochs in a cycle.
        mult_factor: Scale epochs_to_restart after each full cycle completion.
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: http://arxiv.org/abs/1608.03983
    '''
    def __init__(self,
                 min_lr,
                 max_lr,
                 steps_per_epoch,
                 lr_decay=1,
                 cycle_length=10,
                 mult_factor=2):

        self.min_lr = min_lr
        self.max_lr = max_lr
        self.lr_decay = lr_decay

        self.batch_since_restart = 0
        self.next_restart = cycle_length

        self.steps_per_epoch = steps_per_epoch

        self.cycle_length = cycle_length
        self.mult_factor = mult_factor

        self.history = {}

    def clr(self):
        '''Calculate the learning rate.'''
        fraction_to_restart = self.batch_since_restart / (self.steps_per_epoch * self.cycle_length)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + np.cos(fraction_to_restart * np.pi))
        return lr

    def on_train_begin(self, logs={}):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.max_lr)

    def on_batch_end(self, batch, logs={}):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        self.batch_since_restart += 1
        K.set_value(self.model.optimizer.lr, self.clr())

    def on_epoch_end(self, epoch, logs={}):
        '''Check for end of current cycle, apply restarts when necessary.'''
        if epoch + 1 == self.next_restart:
            self.batch_since_restart = 0
            self.cycle_length = np.ceil(self.cycle_length * self.mult_factor)
            self.next_restart += self.cycle_length
            self.max_lr *= self.lr_decay
            self.best_weights = self.model.get_weights()

    def on_train_end(self, logs={}):
        '''Set weights to the values from the end of the most recent cycle for best performance.'''
        self.model.set_weights(self.best_weights)

# %%
#Data augmentation
import cv2

affine_seq = iaa.Sequential([
# General
    iaa.SomeOf((1, 2),
               [iaa.Fliplr(0.5),
                iaa.Affine(rotate=(-10, 10),
                           translate_percent={"x": (-0.05, 0.05)},
                           mode='edge'),
                # iaa.CropAndPad(percent=((0.0, 0.0), (0.05, 0.0), (0.0, 0.0), (0.05, 0.0)))
                ]),
    # Deformations
    iaa.Sometimes(0.3, iaa.PiecewiseAffine(scale=(0.04, 0.08))),
    iaa.Sometimes(0.3, iaa.PerspectiveTransform(scale=(0.05, 0.1))),
], random_order=True)

intensity_seq = iaa.Sequential([
    iaa.Invert(0.3),
    iaa.Sometimes(0.3, iaa.ContrastNormalization((0.5, 1.5))),
    iaa.OneOf([
        iaa.Noop(),
        iaa.Sequential([
            iaa.OneOf([
                iaa.Add((-10, 10)),
                iaa.AddElementwise((-10, 10)),
                iaa.Multiply((0.95, 1.05)),
                iaa.MultiplyElementwise((0.95, 1.05)),
            ]),
        ]),
        iaa.OneOf([
            iaa.GaussianBlur(sigma=(0.0, 1.0)),
            iaa.AverageBlur(k=(2, 5)),
            iaa.MedianBlur(k=(3, 5))
        ])
    ])
], random_order=False)

def augment(x, y):
    sometimes = lambda aug: iaa.Sometimes(0.3, aug)

    seq = iaa.Sequential([
        iaa.Fliplr(0.5), # horizontally flip
        sometimes(iaa.Add((-10, 10))),
#        iaa.OneOf([
#            iaa.Noop(),
#            iaa.PerspectiveTransform(scale=(0.04, 0.08)),
#            iaa.Add((-10, 10)),
#            iaa.ContrastNormalization((0.75, 1.5)), 
#            iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)),
#            iaa.EdgeDetect(alpha=(0, 0.7)),
#            iaa.Noop(),
#            sometimes(iaa.OneOf([
#                        iaa.EdgeDetect(alpha=(0, 0.7)),
#                        iaa.DirectedEdgeDetect(
#                            alpha=(0, 0.7), direction=(0.0, 1.0)
#                   ),
#                ])),
#        ]),
        #sometimes(iaa.CropAndPad(
        #        percent=(-0.2, 0.2),
        #        pad_mode=["reflect"]
        #    )),
#        sometimes(iaa.Sequential([
#            iaa.Crop(percent=(0.2), keep_size=False),
#            iaa.Scale({"height": img_size_target, "width": img_size_target}),
#            iaa.Pad(percent=(0.2), pad_mode=["reflect"])
#        ])),
        
    ])._to_deterministic()
    images_aug_x = seq.augment_images(x)
    images_aug_y = seq.augment_images(y)
    return np.array(images_aug_x), np.array(images_aug_y)


# Return augmented images/masks arrays of batch size
def generator(features, labels, batch_size, repeat=1):
    # create empty arrays to contain batch of features and labels
    batch_features = np.zeros((batch_size, img_size_target, img_size_target, features.shape[3]))
    batch_labels = np.zeros((batch_size, img_size_target, img_size_target, labels.shape[3]))
    print(batch_features.shape)
    while True:
        # Fill arrays of batch size with augmented data taken randomly from full passed arrays
        indexes = random.sample(range(len(features)), batch_size)*repeat
        # Perform the exactly the same augmentation for X and y
        random_augmented_images, random_augmented_labels = \
            augment(np.apply_along_axis(np.squeeze, 1, features[indexes]*255).astype(np.uint8),
                    np.apply_along_axis(np.squeeze, 1, labels[indexes]*255).astype(np.uint8))

        yield add_depth_coord(random_augmented_images/255), random_augmented_labels/255
        
#x_train = np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 3)
#y_train = np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 3) 
#x_test= np.array(test_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 3)

x_train = np.array(train_df.images.tolist()).reshape(-1, img_size_target, img_size_target, 1)
y_train = np.array(train_df.masks.tolist()).reshape(-1, img_size_target, img_size_target, 1)
train_cls = np.array(train_df.coverage_class)
gc.collect()
#x_train, y_train, train_cls = augment(train_df)
# Out:
# 0

# %%
#Score the model and do a threshold optimization by the best IoU.

# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in


    true_objects = 2
    pred_objects = 2

    #  if all zeros, original code  generate wrong  bins [-0.5 0 0.5],
    temp1 = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=([0,0.5,1], [0,0.5, 1]))

    intersection = temp1[0]

    area_true = np.histogram(labels,bins=[0,0.5,1])[0]
    area_pred = np.histogram(y_pred, bins=[0,0.5,1])[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection
      
    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    intersection[intersection == 0] = 1e-9
    
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
"""
used for converting the decoded image to rle mask
Fast compared to previous one
"""
def rle_encode(im):
    '''
    im: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = im.flatten(order = 'F')
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
x_test = np.array(
    [(np.array(
        load_img("../data/raw/test/images/{}.png".format(idx),
                 color_mode = "grayscale",))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(
                        -1, img_size_target, img_size_target, 1)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))

# %%
from sklearn.model_selection import StratifiedKFold, KFold
def get_adv_cv(data, adv_class=None, folds=FOLDS):
    if len(adv_class)>0:
        print(len(data),len(adv_class))
        assert len(data) == len(adv_class)
        kfold_selector = StratifiedKFold(n_splits=folds, random_state=SEED, shuffle=True)
        return [(train_idx, val_idx) for train_idx, val_idx in kfold_selector.split(data, adv_class)]
    else:
        folds = KFold(n_splits=folds, shuffle=True, random_state=SEED)
        return folds.split(data)

def filter_xy(x, y, th=10): #32
    y = np.array([img if np.sum(img) > 100 else np.zeros_like(img) for img in y])
    y_s = np.array([i.sum() for i in y])
    return x[(y_s==0) | (y_s>th)], y[(y_s==0) | (y_s>th)]

# %%
metric = 'my_iou_metric'
val_metric = 'val_' + metric
restore_from_file = True

metric_lov = 'my_iou_metric_2'
val_metric_lov = 'val_' + metric_lov

early_stopping = EarlyStopping(monitor=val_metric, mode='max', patience=20, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor=val_metric, mode='max', factor=0.25, patience=10,
                              min_lr=0.0001, verbose=1)

early_stopping_lov = EarlyStopping(monitor=val_metric_lov, mode='max', patience=20, verbose=1)

reduce_lr_lov = ReduceLROnPlateau(monitor=val_metric_lov, mode='max', factor=0.25, patience=10,
                                  min_lr=0.00005, verbose=1)

epochs = 400
batch_size = 128
#optimizer = RMSprop(lr=0.0001)
train_cls = np.array(train_df.coverage_class)

def get_oof(x_train, y, x_test):
    ntrain = x_train.shape[0]
    ntest = x_test.shape[0]
    history = {}
    threshold_best = {}
    
    oof_train = np.zeros((ntrain, img_size_ori, img_size_ori))
    oof_test = np.zeros((ntest, img_size_ori, img_size_ori))
    oof_test_skf = np.empty((FOLDS, ntest, img_size_ori, img_size_ori))
    model = None
    
    for i, (train_index, test_index) in enumerate(get_adv_cv(x_train, train_cls, FOLDS)):
        gc.collect()
        print('\nFold {}'.format(i))  
        file_name = "../models/keras_unet_resnet_{0}_f{1}_{2}_v{3}.model".format(SEED, FOLDS, i, VERSION)
        print(file_name)
        y_valid_ori = np.array([y[idx] for idx in test_index])

        model_checkpoint = ModelCheckpoint(file_name,  monitor=val_metric, mode='max',
                                           save_best_only=True, verbose=1)   
        
        x_tr = x_train[train_index, :]
        y_tr = y[train_index]
        x_te = add_depth_coord(x_train[test_index, :])
        y_te = y[test_index]
        print(x_tr.shape, y_tr.shape, x_te.shape)
        x_tr, y_tr = filter_xy(x_tr, y_tr)
        print(x_tr.shape, y_tr.shape, x_te.shape)

        
        x_te_ext = np.append(x_te, [np.fliplr(x) for x in x_te], axis=0)
        y_te_ext = np.append(y_te, [np.fliplr(x) for x in y_te], axis=0)
        #g = generator(x_te, y_te, x_te.shape[0], 4)
        #x_te, y_te = next(g)
        print('new validation size:', x_te_ext.shape, y_te_ext.shape)

        learning_rate = 0.01
        depth = 1
        if DEPTH:
            depth = 3
        input_layer = Input((img_size_target, img_size_target, depth))
        output_layer = build_model(input_layer, 16, 0.5)

        model1 = Model(input_layer, output_layer)
        c = optimizers.adam(lr = learning_rate)
        model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])
        
        
        if (not restore_from_file) or (not os.path.isfile(file_name)):           
            history[(i, 0)] = model1.fit_generator(generator(x_tr, y_tr, batch_size),
                                                   validation_data=[x_te_ext, y_te_ext], 
                                                   epochs=epochs,
                                                   callbacks=[early_stopping, model_checkpoint, reduce_lr],
                                                   use_multiprocessing=True,
                                                   workers=1,
                                                   steps_per_epoch=len(x_tr)*2/batch_size,
                                                  )          

            
                    
            model_lov = load_model(file_name, custom_objects={metric: my_iou_metric})
            input_x = model_lov.layers[0].input
            output_layer = model_lov.layers[-1].input
            model = Model(input_x, output_layer)
            learning_rate = 0.005
            c = optimizers.adam(lr = learning_rate)
            model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])
    
            model_checkpoint = ModelCheckpoint(file_name,
                                               monitor=val_metric_lov,
                                               mode='max',
                                               save_best_only=True,
                                               verbose=1)

            history[(i, 1)] = model.fit_generator(generator(x_tr, y_tr, batch_size),
                                                  validation_data=[x_te_ext, y_te_ext], 
                                                  epochs=epochs,
                                                  callbacks=[early_stopping_lov, model_checkpoint, reduce_lr_lov],
                                                  use_multiprocessing=True,
                                                  workers=1,
                                                  steps_per_epoch=len(x_tr)*2/batch_size,
                                                 )              
            schedule = SGDRScheduler(min_lr=1e-8, max_lr=3e-2, steps_per_epoch=np.ceil(len(x_tr)*2/batch_size),
                        lr_decay=0.8, cycle_length=5, mult_factor=1.5)            
            history[(i, 2)] = model.fit_generator(generator(x_tr, y_tr, batch_size),
                                                  validation_data=[x_te_ext, y_te_ext], 
                                                  epochs=epochs,
                                                  callbacks=[early_stopping_lov, model_checkpoint, schedule],
                                                  use_multiprocessing=True,
                                                  workers=1,
                                                  steps_per_epoch=len(x_tr)*2/batch_size,
                                                 )             
        else:
            model = load_model(file_name, custom_objects={'my_iou_metric_2': my_iou_metric_2,
                                                         'lovasz_loss':lovasz_loss})

        
        #tta_model = model#tta_segmentation(model, h_flip=True, merge='mean')
        #tta_model = TTA_ModelWrapper(model)
        
        oof_train[test_index] = \
            np.array([x for x in predict_result(model, x_te, img_size_target).reshape(-1, img_size_target, img_size_target)])
        oof_test_skf[i, :] = \
            np.array([x for x in predict_result(model, add_depth_coord(x_test), img_size_target).reshape(-1, img_size_target, img_size_target)])


        thresholds = np.linspace(1e-5, .9999, 50)
        thresholds = np.log(thresholds/(1-thresholds))
        print(thresholds)
        ious = np.array([
            iou_metric_batch(
                y_valid_ori, np.int32(
                    oof_train[test_index] > threshold)) for threshold in tqdm_notebook(thresholds)])        

        threshold_best_index = np.argmax(ious)
        print('ious: ', ious)
        iou_best = ious[threshold_best_index]
        threshold_best[i] = thresholds[threshold_best_index]
        print('threshold_best[{0}]: {1}'.format(i, threshold_best[i]))
        
        print('iou_best: ', iou_best)        
        
        oof_train[test_index] = oof_train[test_index] > threshold_best[i]
        oof_test_skf[i, :] = oof_test_skf[i, :] > threshold_best[i]
        oof_test[:] += oof_test_skf[i, :] / FOLDS
        
        del model
        #del tta_model
        
    #oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train, oof_test, oof_test_skf, history, threshold_best

# %%
oof_train, oof_test, oof_test_skf, k_history, threshold_best = get_oof(x_train, y_train, x_test)
#0.802860696517413 0.8163545568039949 0.8210000000000001 0.814142678347935 0.8138190954773868
# Out:
# 4000 4000
#
# Fold 0
# ../models/keras_unet_resnet_42_f5_0_v31.model
# (3196, 101, 101, 1) (3196, 101, 101, 1) (804, 101, 101, 1)
# (3196, 101, 101, 1) (3196, 101, 101, 1) (804, 101, 101, 1)
# new validation size: (1608, 101, 101, 1) (1608, 101, 101, 1)
# [-11.51291546  -3.87081317  -3.15685969  -2.7299723   -2.42035452
#   -2.17476509  -1.96947293  -1.79180614  -1.63418879  -1.49172293
#   -1.3610532   -1.23977529  -1.12610286  -1.018668    -0.91639573
#   -0.81842178  -0.7240367   -0.63264686  -0.54374629  -0.45689595
#   -0.37170802  -0.28783374  -0.20495362  -0.12276948  -0.04099758
#    0.04063743   0.12240813   0.20458984   0.28746624   0.37133546
#    0.45651685   0.54335904   0.63224965   0.72362745   0.81799809
#    0.91595476   1.0182063    1.12561621   1.23925838   1.36049918
#    1.49112277   1.6335301    1.79107131   1.96863562   2.17378323
#    2.41915463   2.72840758   3.15456358   3.86632265   9.21024037]
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# ious:  [0.26902985 0.76579602 0.77823383 0.78681592 0.79303483 0.79626866
#  0.79726368 0.79813433 0.79937811 0.80037313 0.80174129 0.80236318
#  0.8050995  0.80721393 0.80721393 0.80771144 0.80733831 0.80771144
#  0.80783582 0.80771144 0.80733831 0.80833333 0.80820896 0.80746269
#  0.80733831 0.80820896 0.80746269 0.80696517 0.80646766 0.80621891
#  0.8068408  0.80820896 0.80808458 0.80721393 0.80659204 0.80584577
#  0.80472637 0.80460199 0.80422886 0.80323383 0.80248756 0.80149254
#  0.79950249 0.79751244 0.79552239 0.7909204  0.78731343 0.77960199
#  0.7659204  0.58855721]
# threshold_best[0]: -0.28783374076181156
# iou_best:  0.8083333333333335
#
# Fold 1
# ../models/keras_unet_resnet_42_f5_1_v31.model
# (3199, 101, 101, 1) (3199, 101, 101, 1) (801, 101, 101, 1)
# (3199, 101, 101, 1) (3199, 101, 101, 1) (801, 101, 101, 1)
# new validation size: (1602, 101, 101, 1) (1602, 101, 101, 1)
# Epoch 1/400
# (128, 101, 101, 1)
# 50/49 [==============================] - 43s 867ms/step - loss: 0.5060 - my_iou_metric: 0.2321 - val_loss: 3.7069 - val_my_iou_metric: 0.3901
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.39014, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 2/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.3439 - my_iou_metric: 0.3500 - val_loss: 2.8851 - val_my_iou_metric: 0.3277
#
# Epoch 00002: val_my_iou_metric did not improve from 0.39014
# Epoch 3/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.3246 - my_iou_metric: 0.4699 - val_loss: 1.1913 - val_my_iou_metric: 0.0489
#
# Epoch 00003: val_my_iou_metric did not improve from 0.39014
# Epoch 4/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.2959 - my_iou_metric: 0.5215 - val_loss: 0.5692 - val_my_iou_metric: 0.2165
#
# Epoch 00004: val_my_iou_metric did not improve from 0.39014
# Epoch 5/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.3064 - my_iou_metric: 0.5485 - val_loss: 1.4688 - val_my_iou_metric: 0.1603
#
# Epoch 00005: val_my_iou_metric did not improve from 0.39014
# Epoch 6/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.2618 - my_iou_metric: 0.5950 - val_loss: 0.4923 - val_my_iou_metric: 0.4095
#
# Epoch 00006: val_my_iou_metric improved from 0.39014 to 0.40949, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 7/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.2417 - my_iou_metric: 0.5980 - val_loss: 0.6960 - val_my_iou_metric: 0.4848
#
# Epoch 00007: val_my_iou_metric improved from 0.40949 to 0.48477, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 8/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.2371 - my_iou_metric: 0.6051 - val_loss: 0.5466 - val_my_iou_metric: 0.4463
#
# Epoch 00008: val_my_iou_metric did not improve from 0.48477
# Epoch 9/400
# 50/49 [==============================] - 27s 540ms/step - loss: 0.2416 - my_iou_metric: 0.6245 - val_loss: 0.3959 - val_my_iou_metric: 0.4192
#
# Epoch 00009: val_my_iou_metric did not improve from 0.48477
# Epoch 10/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.2110 - my_iou_metric: 0.6428 - val_loss: 1.8909 - val_my_iou_metric: 0.3908
#
# Epoch 00010: val_my_iou_metric did not improve from 0.48477
# Epoch 11/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.2358 - my_iou_metric: 0.6071 - val_loss: 0.4742 - val_my_iou_metric: 0.5345
#
# Epoch 00011: val_my_iou_metric improved from 0.48477 to 0.53452, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 12/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.2057 - my_iou_metric: 0.6514 - val_loss: 0.4612 - val_my_iou_metric: 0.4825
#
# Epoch 00012: val_my_iou_metric did not improve from 0.53452
# Epoch 13/400
# 50/49 [==============================] - 27s 540ms/step - loss: 0.1952 - my_iou_metric: 0.6765 - val_loss: 0.5009 - val_my_iou_metric: 0.4866
#
# Epoch 00013: val_my_iou_metric did not improve from 0.53452
# Epoch 14/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1913 - my_iou_metric: 0.6756 - val_loss: 0.2239 - val_my_iou_metric: 0.6252
#
# Epoch 00014: val_my_iou_metric improved from 0.53452 to 0.62516, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 15/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.1862 - my_iou_metric: 0.6869 - val_loss: 0.3265 - val_my_iou_metric: 0.5144
#
# Epoch 00015: val_my_iou_metric did not improve from 0.62516
# Epoch 16/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.1848 - my_iou_metric: 0.6910 - val_loss: 0.2377 - val_my_iou_metric: 0.6332
#
# Epoch 00016: val_my_iou_metric improved from 0.62516 to 0.63321, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 17/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1759 - my_iou_metric: 0.6994 - val_loss: 0.2800 - val_my_iou_metric: 0.6015
#
# Epoch 00017: val_my_iou_metric did not improve from 0.63321
# Epoch 18/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.1706 - my_iou_metric: 0.7041 - val_loss: 0.2755 - val_my_iou_metric: 0.6502
#
# Epoch 00018: val_my_iou_metric improved from 0.63321 to 0.65019, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 19/400
# 50/49 [==============================] - 27s 535ms/step - loss: 0.1663 - my_iou_metric: 0.7203 - val_loss: 0.3148 - val_my_iou_metric: 0.5829
#
# Epoch 00019: val_my_iou_metric did not improve from 0.65019
# Epoch 20/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.1620 - my_iou_metric: 0.7183 - val_loss: 0.2098 - val_my_iou_metric: 0.6747
#
# Epoch 00020: val_my_iou_metric improved from 0.65019 to 0.67472, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 21/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1655 - my_iou_metric: 0.7231 - val_loss: 0.2690 - val_my_iou_metric: 0.6402
#
# Epoch 00021: val_my_iou_metric did not improve from 0.67472
# Epoch 22/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.1579 - my_iou_metric: 0.7222 - val_loss: 0.2791 - val_my_iou_metric: 0.6838
#
# Epoch 00022: val_my_iou_metric improved from 0.67472 to 0.68377, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 23/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.1827 - my_iou_metric: 0.6835 - val_loss: 0.3561 - val_my_iou_metric: 0.5750
#
# Epoch 00023: val_my_iou_metric did not improve from 0.68377
# Epoch 24/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.1556 - my_iou_metric: 0.7306 - val_loss: 0.2326 - val_my_iou_metric: 0.5895
#
# Epoch 00024: val_my_iou_metric did not improve from 0.68377
# Epoch 25/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.1569 - my_iou_metric: 0.7305 - val_loss: 0.3573 - val_my_iou_metric: 0.5667
#
# Epoch 00025: val_my_iou_metric did not improve from 0.68377
# Epoch 26/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.1477 - my_iou_metric: 0.7373 - val_loss: 0.2269 - val_my_iou_metric: 0.6343
#
# Epoch 00026: val_my_iou_metric did not improve from 0.68377
# Epoch 27/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.1421 - my_iou_metric: 0.7511 - val_loss: 0.3907 - val_my_iou_metric: 0.5523
#
# Epoch 00027: val_my_iou_metric did not improve from 0.68377
# Epoch 28/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.1420 - my_iou_metric: 0.7554 - val_loss: 0.2161 - val_my_iou_metric: 0.6560
#
# Epoch 00028: val_my_iou_metric did not improve from 0.68377
# Epoch 29/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.1426 - my_iou_metric: 0.7550 - val_loss: 0.1811 - val_my_iou_metric: 0.6934
#
# Epoch 00029: val_my_iou_metric improved from 0.68377 to 0.69338, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 30/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.1308 - my_iou_metric: 0.7647 - val_loss: 0.1697 - val_my_iou_metric: 0.6940
#
# Epoch 00030: val_my_iou_metric improved from 0.69338 to 0.69401, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 31/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1285 - my_iou_metric: 0.7739 - val_loss: 0.1923 - val_my_iou_metric: 0.6874
#
# Epoch 00031: val_my_iou_metric did not improve from 0.69401
# Epoch 32/400
# 50/49 [==============================] - 27s 535ms/step - loss: 0.1219 - my_iou_metric: 0.7774 - val_loss: 0.2000 - val_my_iou_metric: 0.6718
#
# Epoch 00032: val_my_iou_metric did not improve from 0.69401
# Epoch 33/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1373 - my_iou_metric: 0.7539 - val_loss: 0.2097 - val_my_iou_metric: 0.6798
#
# Epoch 00033: val_my_iou_metric did not improve from 0.69401
# Epoch 34/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.1226 - my_iou_metric: 0.7827 - val_loss: 0.2285 - val_my_iou_metric: 0.6068
#
# Epoch 00034: val_my_iou_metric did not improve from 0.69401
# Epoch 35/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.1230 - my_iou_metric: 0.7845 - val_loss: 0.4447 - val_my_iou_metric: 0.5910
#
# Epoch 00035: val_my_iou_metric did not improve from 0.69401
# Epoch 36/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.1264 - my_iou_metric: 0.7642 - val_loss: 0.2117 - val_my_iou_metric: 0.6635
#
# Epoch 00036: val_my_iou_metric did not improve from 0.69401
# Epoch 37/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1358 - my_iou_metric: 0.7679 - val_loss: 0.1886 - val_my_iou_metric: 0.7014
#
# Epoch 00037: val_my_iou_metric improved from 0.69401 to 0.70137, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 38/400
# 50/49 [==============================] - 27s 541ms/step - loss: 0.1248 - my_iou_metric: 0.7831 - val_loss: 0.1720 - val_my_iou_metric: 0.7274
#
# Epoch 00038: val_my_iou_metric improved from 0.70137 to 0.72740, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 39/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.1198 - my_iou_metric: 0.7885 - val_loss: 0.2076 - val_my_iou_metric: 0.7209
#
# Epoch 00039: val_my_iou_metric did not improve from 0.72740
# Epoch 40/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1142 - my_iou_metric: 0.7893 - val_loss: 0.2375 - val_my_iou_metric: 0.6745
#
# Epoch 00040: val_my_iou_metric did not improve from 0.72740
# Epoch 41/400
# 50/49 [==============================] - 27s 535ms/step - loss: 0.1143 - my_iou_metric: 0.7922 - val_loss: 0.1856 - val_my_iou_metric: 0.7036
#
# Epoch 00041: val_my_iou_metric did not improve from 0.72740
# Epoch 42/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1171 - my_iou_metric: 0.7908 - val_loss: 0.1969 - val_my_iou_metric: 0.6953
#
# Epoch 00042: val_my_iou_metric did not improve from 0.72740
# Epoch 43/400
# 50/49 [==============================] - 27s 535ms/step - loss: 0.1063 - my_iou_metric: 0.7973 - val_loss: 0.1620 - val_my_iou_metric: 0.7232
#
# Epoch 00043: val_my_iou_metric did not improve from 0.72740
# Epoch 44/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.1097 - my_iou_metric: 0.7962 - val_loss: 0.1672 - val_my_iou_metric: 0.7312
#
# Epoch 00044: val_my_iou_metric improved from 0.72740 to 0.73121, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 45/400
# 50/49 [==============================] - 27s 535ms/step - loss: 0.1024 - my_iou_metric: 0.7942 - val_loss: 0.2292 - val_my_iou_metric: 0.7104
#
# Epoch 00045: val_my_iou_metric did not improve from 0.73121
# Epoch 46/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1090 - my_iou_metric: 0.7930 - val_loss: 0.1869 - val_my_iou_metric: 0.7220
#
# Epoch 00046: val_my_iou_metric did not improve from 0.73121
# Epoch 47/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1081 - my_iou_metric: 0.7941 - val_loss: 0.2829 - val_my_iou_metric: 0.6570
#
# Epoch 00047: val_my_iou_metric did not improve from 0.73121
# Epoch 48/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.1036 - my_iou_metric: 0.7968 - val_loss: 0.2077 - val_my_iou_metric: 0.7155
#
# Epoch 00048: val_my_iou_metric did not improve from 0.73121
# Epoch 49/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0972 - my_iou_metric: 0.8053 - val_loss: 0.1782 - val_my_iou_metric: 0.7162
#
# Epoch 00049: val_my_iou_metric did not improve from 0.73121
# Epoch 50/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0962 - my_iou_metric: 0.8114 - val_loss: 0.2340 - val_my_iou_metric: 0.7257
#
# Epoch 00050: val_my_iou_metric did not improve from 0.73121
# Epoch 51/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.1024 - my_iou_metric: 0.8044 - val_loss: 0.2147 - val_my_iou_metric: 0.6958
#
# Epoch 00051: val_my_iou_metric did not improve from 0.73121
# Epoch 52/400
# 50/49 [==============================] - 27s 533ms/step - loss: 0.0969 - my_iou_metric: 0.8050 - val_loss: 0.1666 - val_my_iou_metric: 0.7286
#
# Epoch 00052: val_my_iou_metric did not improve from 0.73121
# Epoch 53/400
# 50/49 [==============================] - 27s 535ms/step - loss: 0.1039 - my_iou_metric: 0.7941 - val_loss: 0.2740 - val_my_iou_metric: 0.6001
#
# Epoch 00053: val_my_iou_metric did not improve from 0.73121
# Epoch 54/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.0972 - my_iou_metric: 0.8065 - val_loss: 0.2095 - val_my_iou_metric: 0.6537
#
# Epoch 00054: val_my_iou_metric did not improve from 0.73121
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 55/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0842 - my_iou_metric: 0.8228 - val_loss: 0.1714 - val_my_iou_metric: 0.7425
#
# Epoch 00055: val_my_iou_metric improved from 0.73121 to 0.74251, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 56/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0826 - my_iou_metric: 0.8295 - val_loss: 0.1630 - val_my_iou_metric: 0.7514
#
# Epoch 00056: val_my_iou_metric improved from 0.74251 to 0.75144, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 57/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0738 - my_iou_metric: 0.8390 - val_loss: 0.1757 - val_my_iou_metric: 0.7411
#
# Epoch 00057: val_my_iou_metric did not improve from 0.75144
# Epoch 58/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0764 - my_iou_metric: 0.8274 - val_loss: 0.1606 - val_my_iou_metric: 0.7632
#
# Epoch 00058: val_my_iou_metric improved from 0.75144 to 0.76323, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 59/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0703 - my_iou_metric: 0.8402 - val_loss: 0.1638 - val_my_iou_metric: 0.7575
#
# Epoch 00059: val_my_iou_metric did not improve from 0.76323
# Epoch 60/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.0692 - my_iou_metric: 0.8396 - val_loss: 0.1787 - val_my_iou_metric: 0.7615
#
# Epoch 00060: val_my_iou_metric did not improve from 0.76323
# Epoch 61/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0696 - my_iou_metric: 0.8389 - val_loss: 0.1818 - val_my_iou_metric: 0.7524
#
# Epoch 00061: val_my_iou_metric did not improve from 0.76323
# Epoch 62/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.0709 - my_iou_metric: 0.8303 - val_loss: 0.1739 - val_my_iou_metric: 0.7560
#
# Epoch 00062: val_my_iou_metric did not improve from 0.76323
# Epoch 63/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.0655 - my_iou_metric: 0.8427 - val_loss: 0.1711 - val_my_iou_metric: 0.7669
#
# Epoch 00063: val_my_iou_metric improved from 0.76323 to 0.76685, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 64/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.0695 - my_iou_metric: 0.8377 - val_loss: 0.1913 - val_my_iou_metric: 0.7571
#
# Epoch 00064: val_my_iou_metric did not improve from 0.76685
# Epoch 65/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.0679 - my_iou_metric: 0.8388 - val_loss: 0.1812 - val_my_iou_metric: 0.7481
#
# Epoch 00065: val_my_iou_metric did not improve from 0.76685
# Epoch 66/400
# 50/49 [==============================] - 27s 535ms/step - loss: 0.0645 - my_iou_metric: 0.8455 - val_loss: 0.2023 - val_my_iou_metric: 0.7556
#
# Epoch 00066: val_my_iou_metric did not improve from 0.76685
# Epoch 67/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.0657 - my_iou_metric: 0.8348 - val_loss: 0.1922 - val_my_iou_metric: 0.7614
#
# Epoch 00067: val_my_iou_metric did not improve from 0.76685
# Epoch 68/400
# 50/49 [==============================] - 27s 535ms/step - loss: 0.0641 - my_iou_metric: 0.8419 - val_loss: 0.1878 - val_my_iou_metric: 0.7486
#
# Epoch 00068: val_my_iou_metric did not improve from 0.76685
# Epoch 69/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.0677 - my_iou_metric: 0.8360 - val_loss: 0.1846 - val_my_iou_metric: 0.7565
#
# Epoch 00069: val_my_iou_metric did not improve from 0.76685
# Epoch 70/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.0679 - my_iou_metric: 0.8366 - val_loss: 0.1967 - val_my_iou_metric: 0.7425
#
# Epoch 00070: val_my_iou_metric did not improve from 0.76685
# Epoch 71/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0632 - my_iou_metric: 0.8459 - val_loss: 0.2064 - val_my_iou_metric: 0.7562
#
# Epoch 00071: val_my_iou_metric did not improve from 0.76685
# Epoch 72/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0608 - my_iou_metric: 0.8510 - val_loss: 0.1911 - val_my_iou_metric: 0.7632
#
# Epoch 00072: val_my_iou_metric did not improve from 0.76685
# Epoch 73/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0649 - my_iou_metric: 0.8450 - val_loss: 0.2044 - val_my_iou_metric: 0.7497
#
# Epoch 00073: val_my_iou_metric did not improve from 0.76685
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 74/400
# 50/49 [==============================] - 27s 540ms/step - loss: 0.0597 - my_iou_metric: 0.8537 - val_loss: 0.1816 - val_my_iou_metric: 0.7664
#
# Epoch 00074: val_my_iou_metric did not improve from 0.76685
# Epoch 75/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0560 - my_iou_metric: 0.8570 - val_loss: 0.1849 - val_my_iou_metric: 0.7625
#
# Epoch 00075: val_my_iou_metric did not improve from 0.76685
# Epoch 76/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.0554 - my_iou_metric: 0.8596 - val_loss: 0.1832 - val_my_iou_metric: 0.7658
#
# Epoch 00076: val_my_iou_metric did not improve from 0.76685
# Epoch 77/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0563 - my_iou_metric: 0.8553 - val_loss: 0.1879 - val_my_iou_metric: 0.7634
#
# Epoch 00077: val_my_iou_metric did not improve from 0.76685
# Epoch 78/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0515 - my_iou_metric: 0.8624 - val_loss: 0.1860 - val_my_iou_metric: 0.7701
#
# Epoch 00078: val_my_iou_metric improved from 0.76685 to 0.77010, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 79/400
# 50/49 [==============================] - 27s 541ms/step - loss: 0.0556 - my_iou_metric: 0.8522 - val_loss: 0.1856 - val_my_iou_metric: 0.7672
#
# Epoch 00079: val_my_iou_metric did not improve from 0.77010
# Epoch 80/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0585 - my_iou_metric: 0.8499 - val_loss: 0.1840 - val_my_iou_metric: 0.7652
#
# Epoch 00080: val_my_iou_metric did not improve from 0.77010
# Epoch 81/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0529 - my_iou_metric: 0.8539 - val_loss: 0.1920 - val_my_iou_metric: 0.7649
#
# Epoch 00081: val_my_iou_metric did not improve from 0.77010
# Epoch 82/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0570 - my_iou_metric: 0.8568 - val_loss: 0.1958 - val_my_iou_metric: 0.7655
#
# Epoch 00082: val_my_iou_metric did not improve from 0.77010
# Epoch 83/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0567 - my_iou_metric: 0.8532 - val_loss: 0.1974 - val_my_iou_metric: 0.7629
#
# Epoch 00083: val_my_iou_metric did not improve from 0.77010
# Epoch 84/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0535 - my_iou_metric: 0.8590 - val_loss: 0.1997 - val_my_iou_metric: 0.7660
#
# Epoch 00084: val_my_iou_metric did not improve from 0.77010
# Epoch 85/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0542 - my_iou_metric: 0.8571 - val_loss: 0.1996 - val_my_iou_metric: 0.7636
#
# Epoch 00085: val_my_iou_metric did not improve from 0.77010
# Epoch 86/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0529 - my_iou_metric: 0.8526 - val_loss: 0.1977 - val_my_iou_metric: 0.7661
#
# Epoch 00086: val_my_iou_metric did not improve from 0.77010
# Epoch 87/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0537 - my_iou_metric: 0.8617 - val_loss: 0.1928 - val_my_iou_metric: 0.7667
#
# Epoch 00087: val_my_iou_metric did not improve from 0.77010
# Epoch 88/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0553 - my_iou_metric: 0.8495 - val_loss: 0.2000 - val_my_iou_metric: 0.7647
#
# Epoch 00088: val_my_iou_metric did not improve from 0.77010
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 89/400
# 50/49 [==============================] - 27s 541ms/step - loss: 0.0518 - my_iou_metric: 0.8563 - val_loss: 0.1979 - val_my_iou_metric: 0.7655
#
# Epoch 00089: val_my_iou_metric did not improve from 0.77010
# Epoch 90/400
# 50/49 [==============================] - 27s 540ms/step - loss: 0.0521 - my_iou_metric: 0.8587 - val_loss: 0.1979 - val_my_iou_metric: 0.7692
#
# Epoch 00090: val_my_iou_metric did not improve from 0.77010
# Epoch 91/400
# 50/49 [==============================] - 27s 538ms/step - loss: 0.0521 - my_iou_metric: 0.8622 - val_loss: 0.1940 - val_my_iou_metric: 0.7673
#
# Epoch 00091: val_my_iou_metric did not improve from 0.77010
# Epoch 92/400
# 50/49 [==============================] - 27s 540ms/step - loss: 0.0532 - my_iou_metric: 0.8628 - val_loss: 0.1955 - val_my_iou_metric: 0.7677
#
# Epoch 00092: val_my_iou_metric did not improve from 0.77010
# Epoch 93/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0537 - my_iou_metric: 0.8618 - val_loss: 0.2000 - val_my_iou_metric: 0.7664
#
# Epoch 00093: val_my_iou_metric did not improve from 0.77010
# Epoch 94/400
# 50/49 [==============================] - 27s 539ms/step - loss: 0.0510 - my_iou_metric: 0.8546 - val_loss: 0.2018 - val_my_iou_metric: 0.7675
#
# Epoch 00094: val_my_iou_metric did not improve from 0.77010
# Epoch 95/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.0491 - my_iou_metric: 0.8610 - val_loss: 0.2004 - val_my_iou_metric: 0.7680
#
# Epoch 00095: val_my_iou_metric did not improve from 0.77010
# Epoch 96/400
# 50/49 [==============================] - 27s 535ms/step - loss: 0.0499 - my_iou_metric: 0.8635 - val_loss: 0.1988 - val_my_iou_metric: 0.7662
#
# Epoch 00096: val_my_iou_metric did not improve from 0.77010
# Epoch 97/400
# 50/49 [==============================] - 27s 536ms/step - loss: 0.0513 - my_iou_metric: 0.8599 - val_loss: 0.2001 - val_my_iou_metric: 0.7670
#
# Epoch 00097: val_my_iou_metric did not improve from 0.77010
# Epoch 98/400
# 50/49 [==============================] - 27s 537ms/step - loss: 0.0489 - my_iou_metric: 0.8629 - val_loss: 0.2001 - val_my_iou_metric: 0.7670
#
# Epoch 00098: val_my_iou_metric did not improve from 0.77010
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 00098: early stopping
# Epoch 1/400
#
# (128, 101, 101, 1)
# 50/49 [==============================] - 98s 2s/step - loss: -0.3817 - my_iou_metric_2: 0.8559 - val_loss: 0.3253 - val_my_iou_metric_2: 0.7592
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.75918, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 2/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4274 - my_iou_metric_2: 0.8610 - val_loss: 0.2796 - val_my_iou_metric_2: 0.7647
#
# Epoch 00002: val_my_iou_metric_2 improved from 0.75918 to 0.76473, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 3/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4264 - my_iou_metric_2: 0.8595 - val_loss: 0.1878 - val_my_iou_metric_2: 0.7647
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.76473
# Epoch 4/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4431 - my_iou_metric_2: 0.8618 - val_loss: 0.4950 - val_my_iou_metric_2: 0.6914
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.76473
# Epoch 5/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4166 - my_iou_metric_2: 0.8540 - val_loss: 0.2302 - val_my_iou_metric_2: 0.7615
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.76473
# Epoch 6/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4831 - my_iou_metric_2: 0.8683 - val_loss: 0.2870 - val_my_iou_metric_2: 0.7666
#
# Epoch 00006: val_my_iou_metric_2 improved from 0.76473 to 0.76660, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 7/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4527 - my_iou_metric_2: 0.8633 - val_loss: 0.2842 - val_my_iou_metric_2: 0.7583
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.76660
# Epoch 8/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4733 - my_iou_metric_2: 0.8676 - val_loss: 0.5354 - val_my_iou_metric_2: 0.7295
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.76660
# Epoch 9/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4775 - my_iou_metric_2: 0.8688 - val_loss: 0.1928 - val_my_iou_metric_2: 0.7650
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.76660
# Epoch 10/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4961 - my_iou_metric_2: 0.8727 - val_loss: 0.2176 - val_my_iou_metric_2: 0.7693
#
# Epoch 00010: val_my_iou_metric_2 improved from 0.76660 to 0.76929, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 11/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5050 - my_iou_metric_2: 0.8750 - val_loss: 0.2270 - val_my_iou_metric_2: 0.7687
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.76929
# Epoch 12/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4948 - my_iou_metric_2: 0.8709 - val_loss: 0.3126 - val_my_iou_metric_2: 0.7511
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.76929
# Epoch 13/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5035 - my_iou_metric_2: 0.8742 - val_loss: 0.2734 - val_my_iou_metric_2: 0.7559
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.76929
# Epoch 14/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5027 - my_iou_metric_2: 0.8726 - val_loss: 0.2999 - val_my_iou_metric_2: 0.7667
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.76929
# Epoch 15/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5166 - my_iou_metric_2: 0.8770 - val_loss: 0.2939 - val_my_iou_metric_2: 0.7522
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.76929
# Epoch 16/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4693 - my_iou_metric_2: 0.8634 - val_loss: 0.1901 - val_my_iou_metric_2: 0.7716
#
# Epoch 00016: val_my_iou_metric_2 improved from 0.76929 to 0.77160, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 17/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5179 - my_iou_metric_2: 0.8756 - val_loss: 0.3037 - val_my_iou_metric_2: 0.7337
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.77160
# Epoch 18/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5347 - my_iou_metric_2: 0.8795 - val_loss: 0.1836 - val_my_iou_metric_2: 0.7657
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.77160
# Epoch 19/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5326 - my_iou_metric_2: 0.8762 - val_loss: 0.1649 - val_my_iou_metric_2: 0.7684
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.77160
# Epoch 20/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5448 - my_iou_metric_2: 0.8814 - val_loss: 0.2833 - val_my_iou_metric_2: 0.7708
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.77160
# Epoch 21/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5441 - my_iou_metric_2: 0.8790 - val_loss: 0.2483 - val_my_iou_metric_2: 0.7631
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.77160
# Epoch 22/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5230 - my_iou_metric_2: 0.8756 - val_loss: 0.1415 - val_my_iou_metric_2: 0.7690
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.77160
# Epoch 23/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5573 - my_iou_metric_2: 0.8872 - val_loss: 0.6773 - val_my_iou_metric_2: 0.7202
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.77160
# Epoch 24/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5452 - my_iou_metric_2: 0.8810 - val_loss: 0.4462 - val_my_iou_metric_2: 0.7477
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.77160
# Epoch 25/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5438 - my_iou_metric_2: 0.8790 - val_loss: 0.3544 - val_my_iou_metric_2: 0.7653
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.77160
# Epoch 26/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5496 - my_iou_metric_2: 0.8809 - val_loss: 0.5241 - val_my_iou_metric_2: 0.7348
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.77160
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 27/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5836 - my_iou_metric_2: 0.8877 - val_loss: 0.1880 - val_my_iou_metric_2: 0.7816
#
# Epoch 00027: val_my_iou_metric_2 improved from 0.77160 to 0.78159, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 28/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6181 - my_iou_metric_2: 0.8977 - val_loss: 0.1967 - val_my_iou_metric_2: 0.7859
#
# Epoch 00028: val_my_iou_metric_2 improved from 0.78159 to 0.78589, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 29/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6198 - my_iou_metric_2: 0.8953 - val_loss: 0.2470 - val_my_iou_metric_2: 0.7775
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.78589
# Epoch 30/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6356 - my_iou_metric_2: 0.8999 - val_loss: 0.2321 - val_my_iou_metric_2: 0.7780
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.78589
# Epoch 31/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6239 - my_iou_metric_2: 0.8970 - val_loss: 0.2346 - val_my_iou_metric_2: 0.7831
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.78589
# Epoch 32/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6456 - my_iou_metric_2: 0.9014 - val_loss: 0.2222 - val_my_iou_metric_2: 0.7833
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.78589
# Epoch 33/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6389 - my_iou_metric_2: 0.8987 - val_loss: 0.2252 - val_my_iou_metric_2: 0.7861
#
# Epoch 00033: val_my_iou_metric_2 improved from 0.78589 to 0.78608, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 34/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6188 - my_iou_metric_2: 0.8930 - val_loss: 0.2291 - val_my_iou_metric_2: 0.7843
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.78608
# Epoch 35/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6386 - my_iou_metric_2: 0.9009 - val_loss: 0.2651 - val_my_iou_metric_2: 0.7823
#
# Epoch 00035: val_my_iou_metric_2 did not improve from 0.78608
# Epoch 36/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6550 - my_iou_metric_2: 0.9060 - val_loss: 0.2971 - val_my_iou_metric_2: 0.7815
#
# Epoch 00036: val_my_iou_metric_2 did not improve from 0.78608
# Epoch 37/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6546 - my_iou_metric_2: 0.9037 - val_loss: 0.2948 - val_my_iou_metric_2: 0.7800
#
# Epoch 00037: val_my_iou_metric_2 did not improve from 0.78608
# Epoch 38/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6425 - my_iou_metric_2: 0.9008 - val_loss: 0.3056 - val_my_iou_metric_2: 0.7862
#
# Epoch 00038: val_my_iou_metric_2 improved from 0.78608 to 0.78620, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 39/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6393 - my_iou_metric_2: 0.8987 - val_loss: 0.2708 - val_my_iou_metric_2: 0.7816
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.78620
# Epoch 40/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6441 - my_iou_metric_2: 0.9004 - val_loss: 0.3060 - val_my_iou_metric_2: 0.7844
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.78620
# Epoch 41/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6417 - my_iou_metric_2: 0.9000 - val_loss: 0.2823 - val_my_iou_metric_2: 0.7802
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.78620
# Epoch 42/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6690 - my_iou_metric_2: 0.9080 - val_loss: 0.2918 - val_my_iou_metric_2: 0.7851
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.78620
# Epoch 43/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6676 - my_iou_metric_2: 0.9065 - val_loss: 0.2098 - val_my_iou_metric_2: 0.7841
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.78620
# Epoch 44/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6397 - my_iou_metric_2: 0.8985 - val_loss: 0.3310 - val_my_iou_metric_2: 0.7825
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.78620
# Epoch 45/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6517 - my_iou_metric_2: 0.9030 - val_loss: 0.2843 - val_my_iou_metric_2: 0.7846
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.78620
# Epoch 46/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6812 - my_iou_metric_2: 0.9093 - val_loss: 0.3170 - val_my_iou_metric_2: 0.7878
#
# Epoch 00046: val_my_iou_metric_2 improved from 0.78620 to 0.78777, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 47/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6634 - my_iou_metric_2: 0.9051 - val_loss: 0.3037 - val_my_iou_metric_2: 0.7911
#
# Epoch 00047: val_my_iou_metric_2 improved from 0.78777 to 0.79107, saving model to ../models/keras_unet_resnet_42_f5_1_v31.model
# Epoch 48/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6612 - my_iou_metric_2: 0.9032 - val_loss: 0.3025 - val_my_iou_metric_2: 0.7845
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 49/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6646 - my_iou_metric_2: 0.9060 - val_loss: 0.3207 - val_my_iou_metric_2: 0.7816
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 50/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6558 - my_iou_metric_2: 0.9050 - val_loss: 0.3375 - val_my_iou_metric_2: 0.7801
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 51/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6624 - my_iou_metric_2: 0.9065 - val_loss: 0.3229 - val_my_iou_metric_2: 0.7832
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 52/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6818 - my_iou_metric_2: 0.9118 - val_loss: 0.3608 - val_my_iou_metric_2: 0.7825
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 53/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6600 - my_iou_metric_2: 0.9027 - val_loss: 0.3514 - val_my_iou_metric_2: 0.7818
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 54/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6698 - my_iou_metric_2: 0.9063 - val_loss: 0.2836 - val_my_iou_metric_2: 0.7865
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 55/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6709 - my_iou_metric_2: 0.9081 - val_loss: 0.3150 - val_my_iou_metric_2: 0.7868
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 56/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6768 - my_iou_metric_2: 0.9086 - val_loss: 0.3413 - val_my_iou_metric_2: 0.7816
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 57/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6742 - my_iou_metric_2: 0.9097 - val_loss: 0.3393 - val_my_iou_metric_2: 0.7834
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.79107
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 58/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.7025 - my_iou_metric_2: 0.9159 - val_loss: 0.3249 - val_my_iou_metric_2: 0.7828
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 59/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6774 - my_iou_metric_2: 0.9078 - val_loss: 0.3467 - val_my_iou_metric_2: 0.7840
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 60/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6950 - my_iou_metric_2: 0.9138 - val_loss: 0.3430 - val_my_iou_metric_2: 0.7855
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 61/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6890 - my_iou_metric_2: 0.9124 - val_loss: 0.3227 - val_my_iou_metric_2: 0.7840
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 62/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6800 - my_iou_metric_2: 0.9072 - val_loss: 0.3345 - val_my_iou_metric_2: 0.7854
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 63/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6968 - my_iou_metric_2: 0.9135 - val_loss: 0.3259 - val_my_iou_metric_2: 0.7838
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 64/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6983 - my_iou_metric_2: 0.9146 - val_loss: 0.3259 - val_my_iou_metric_2: 0.7868
#
# Epoch 00064: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 65/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6907 - my_iou_metric_2: 0.9118 - val_loss: 0.3449 - val_my_iou_metric_2: 0.7873
#
# Epoch 00065: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 66/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6836 - my_iou_metric_2: 0.9084 - val_loss: 0.3570 - val_my_iou_metric_2: 0.7888
#
# Epoch 00066: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 67/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.6869 - my_iou_metric_2: 0.9119 - val_loss: 0.3522 - val_my_iou_metric_2: 0.7857
#
# Epoch 00067: val_my_iou_metric_2 did not improve from 0.79107
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# Epoch 00067: early stopping
# Epoch 1/400
# (128, 101, 101, 1)
# 50/49 [==============================] - 81s 2s/step - loss: 0.4573 - my_iou_metric_2: 0.6650 - val_loss: 546.8255 - val_my_iou_metric_2: 0.0212
#
# Epoch 00001: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 2/400
# 50/49 [==============================] - 80s 2s/step - loss: 0.2614 - my_iou_metric_2: 0.7098 - val_loss: 27.3154 - val_my_iou_metric_2: 0.3901
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 3/400
# 50/49 [==============================] - 80s 2s/step - loss: 0.1306 - my_iou_metric_2: 0.7454 - val_loss: 1.4588 - val_my_iou_metric_2: 0.3806
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 4/400
# 50/49 [==============================] - 80s 2s/step - loss: 0.0033 - my_iou_metric_2: 0.7729 - val_loss: 1.5206 - val_my_iou_metric_2: 0.4333
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 5/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.0355 - my_iou_metric_2: 0.7775 - val_loss: 0.7209 - val_my_iou_metric_2: 0.6175
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 6/400
# 50/49 [==============================] - 80s 2s/step - loss: 7.2652e-04 - my_iou_metric_2: 0.7691 - val_loss: 1.3056 - val_my_iou_metric_2: 0.4512
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 7/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.0132 - my_iou_metric_2: 0.7717 - val_loss: 1.8537 - val_my_iou_metric_2: 0.3927
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 8/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.1300 - my_iou_metric_2: 0.7982 - val_loss: 0.2514 - val_my_iou_metric_2: 0.7209
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 9/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.1866 - my_iou_metric_2: 0.8097 - val_loss: 0.3633 - val_my_iou_metric_2: 0.6971
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 10/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.2170 - my_iou_metric_2: 0.8153 - val_loss: 0.2909 - val_my_iou_metric_2: 0.7145
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 11/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.3058 - my_iou_metric_2: 0.8355 - val_loss: 0.1881 - val_my_iou_metric_2: 0.7382
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 12/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.3097 - my_iou_metric_2: 0.8317 - val_loss: 0.0926 - val_my_iou_metric_2: 0.7597
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 13/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.3570 - my_iou_metric_2: 0.8423 - val_loss: 0.0363 - val_my_iou_metric_2: 0.7685
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 14/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.2496 - my_iou_metric_2: 0.8225 - val_loss: 0.9611 - val_my_iou_metric_2: 0.5722
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 15/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.2682 - my_iou_metric_2: 0.8233 - val_loss: 0.1040 - val_my_iou_metric_2: 0.7537
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 16/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.2551 - my_iou_metric_2: 0.8217 - val_loss: 0.2891 - val_my_iou_metric_2: 0.7108
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 17/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.2829 - my_iou_metric_2: 0.8269 - val_loss: 0.1367 - val_my_iou_metric_2: 0.7564
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 18/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.3529 - my_iou_metric_2: 0.8429 - val_loss: 0.4528 - val_my_iou_metric_2: 0.7051
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 19/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.3735 - my_iou_metric_2: 0.8462 - val_loss: 0.5737 - val_my_iou_metric_2: 0.6898
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 20/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4301 - my_iou_metric_2: 0.8573 - val_loss: 0.1479 - val_my_iou_metric_2: 0.7479
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 21/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4370 - my_iou_metric_2: 0.8578 - val_loss: 0.2413 - val_my_iou_metric_2: 0.7489
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 22/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4886 - my_iou_metric_2: 0.8703 - val_loss: 0.0903 - val_my_iou_metric_2: 0.7777
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 23/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4862 - my_iou_metric_2: 0.8664 - val_loss: 0.0637 - val_my_iou_metric_2: 0.7801
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 24/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5188 - my_iou_metric_2: 0.8746 - val_loss: 0.0297 - val_my_iou_metric_2: 0.7876
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 25/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5051 - my_iou_metric_2: 0.8725 - val_loss: 0.0170 - val_my_iou_metric_2: 0.7891
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 26/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4231 - my_iou_metric_2: 0.8545 - val_loss: 0.1654 - val_my_iou_metric_2: 0.7602
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 27/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4047 - my_iou_metric_2: 0.8535 - val_loss: 0.9679 - val_my_iou_metric_2: 0.6788
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 28/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4260 - my_iou_metric_2: 0.8543 - val_loss: 0.9131 - val_my_iou_metric_2: 0.6599
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 29/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4120 - my_iou_metric_2: 0.8539 - val_loss: 0.7759 - val_my_iou_metric_2: 0.7028
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 30/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4386 - my_iou_metric_2: 0.8577 - val_loss: 0.2517 - val_my_iou_metric_2: 0.7517
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 31/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4486 - my_iou_metric_2: 0.8595 - val_loss: 0.7980 - val_my_iou_metric_2: 0.6953
#
# Epoch 00031: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 32/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4661 - my_iou_metric_2: 0.8635 - val_loss: 0.1878 - val_my_iou_metric_2: 0.7622
#
# Epoch 00032: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 33/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.4764 - my_iou_metric_2: 0.8652 - val_loss: 0.1271 - val_my_iou_metric_2: 0.7639
#
# Epoch 00033: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 34/400
# 50/49 [==============================] - 80s 2s/step - loss: -0.5199 - my_iou_metric_2: 0.8733 - val_loss: 0.0797 - val_my_iou_metric_2: 0.7736
#
# Epoch 00034: val_my_iou_metric_2 did not improve from 0.79107
# Epoch 35/400
# ...
# Epoch 39/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6032 - my_iou_metric_2: 0.8960 - val_loss: 0.0843 - val_my_iou_metric_2: 0.8025
#
# Epoch 00039: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 40/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6276 - my_iou_metric_2: 0.8999 - val_loss: 0.0724 - val_my_iou_metric_2: 0.8073
#
# Epoch 00040: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 41/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6387 - my_iou_metric_2: 0.9063 - val_loss: 0.0808 - val_my_iou_metric_2: 0.8031
#
# Epoch 00041: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 42/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6259 - my_iou_metric_2: 0.8995 - val_loss: 0.0805 - val_my_iou_metric_2: 0.8071
#
# Epoch 00042: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 43/400
# 51/50 [==============================] - 81s 2s/step - loss: -0.6383 - my_iou_metric_2: 0.9021 - val_loss: 0.0699 - val_my_iou_metric_2: 0.8076
#
# Epoch 00043: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 44/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5138 - my_iou_metric_2: 0.8753 - val_loss: 0.1480 - val_my_iou_metric_2: 0.7780
#
# Epoch 00044: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 45/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.4970 - my_iou_metric_2: 0.8730 - val_loss: 0.1850 - val_my_iou_metric_2: 0.7702
#
# Epoch 00045: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 46/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.4958 - my_iou_metric_2: 0.8716 - val_loss: 0.7624 - val_my_iou_metric_2: 0.6696
#
# Epoch 00046: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 47/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5292 - my_iou_metric_2: 0.8808 - val_loss: 0.5955 - val_my_iou_metric_2: 0.6984
#
# Epoch 00047: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 48/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5135 - my_iou_metric_2: 0.8756 - val_loss: 0.2833 - val_my_iou_metric_2: 0.7670
#
# Epoch 00048: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 49/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5317 - my_iou_metric_2: 0.8797 - val_loss: 0.0686 - val_my_iou_metric_2: 0.7811
#
# Epoch 00049: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 50/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5372 - my_iou_metric_2: 0.8824 - val_loss: 0.0869 - val_my_iou_metric_2: 0.7960
#
# Epoch 00050: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 51/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5655 - my_iou_metric_2: 0.8856 - val_loss: 0.2401 - val_my_iou_metric_2: 0.7810
#
# Epoch 00051: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 52/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5579 - my_iou_metric_2: 0.8855 - val_loss: 0.0855 - val_my_iou_metric_2: 0.7817
#
# Epoch 00052: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 53/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5623 - my_iou_metric_2: 0.8846 - val_loss: 0.1113 - val_my_iou_metric_2: 0.7981
#
# Epoch 00053: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 54/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5707 - my_iou_metric_2: 0.8909 - val_loss: 0.1594 - val_my_iou_metric_2: 0.7762
#
# Epoch 00054: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 55/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5653 - my_iou_metric_2: 0.8881 - val_loss: 0.1086 - val_my_iou_metric_2: 0.7951
#
# Epoch 00055: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 56/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6273 - my_iou_metric_2: 0.9026 - val_loss: 0.3671 - val_my_iou_metric_2: 0.7687
#
# Epoch 00056: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 57/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5939 - my_iou_metric_2: 0.8889 - val_loss: 0.1759 - val_my_iou_metric_2: 0.7887
#
# Epoch 00057: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 58/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6310 - my_iou_metric_2: 0.9016 - val_loss: 0.0897 - val_my_iou_metric_2: 0.8059
#
# Epoch 00058: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 59/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6285 - my_iou_metric_2: 0.8970 - val_loss: 0.1034 - val_my_iou_metric_2: 0.8081
#
# Epoch 00059: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 60/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6544 - my_iou_metric_2: 0.9069 - val_loss: 0.1716 - val_my_iou_metric_2: 0.8011
#
# Epoch 00060: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 61/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6612 - my_iou_metric_2: 0.9090 - val_loss: 0.1357 - val_my_iou_metric_2: 0.8066
#
# Epoch 00061: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 62/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6574 - my_iou_metric_2: 0.9068 - val_loss: 0.1080 - val_my_iou_metric_2: 0.8091
#
# Epoch 00062: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 63/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6772 - my_iou_metric_2: 0.9113 - val_loss: 0.1561 - val_my_iou_metric_2: 0.8059
#
# Epoch 00063: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 64/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6823 - my_iou_metric_2: 0.9140 - val_loss: 0.1269 - val_my_iou_metric_2: 0.8085
#
# Epoch 00064: val_my_iou_metric_2 did not improve from 0.81051
# Epoch 65/400
# 51/50 [==============================] - 81s 2s/step - loss: -0.6960 - my_iou_metric_2: 0.9155 - val_loss: 0.1385 - val_my_iou_metric_2: 0.8152
#
# Epoch 00065: val_my_iou_metric_2 improved from 0.81051 to 0.81521, saving model to ../models/keras_unet_resnet_42_f5_3_v31.model
# Epoch 66/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6948 - my_iou_metric_2: 0.9147 - val_loss: 0.1578 - val_my_iou_metric_2: 0.8134
#
# Epoch 00066: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 67/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6938 - my_iou_metric_2: 0.9152 - val_loss: 0.1786 - val_my_iou_metric_2: 0.8119
#
# Epoch 00067: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 68/400
# 51/50 [==============================] - 81s 2s/step - loss: -0.6930 - my_iou_metric_2: 0.9156 - val_loss: 0.1722 - val_my_iou_metric_2: 0.8140
#
# Epoch 00068: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 69/400
# 51/50 [==============================] - 81s 2s/step - loss: -0.7025 - my_iou_metric_2: 0.9189 - val_loss: 0.1662 - val_my_iou_metric_2: 0.8140
#
# Epoch 00069: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 70/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.7006 - my_iou_metric_2: 0.9171 - val_loss: 0.1654 - val_my_iou_metric_2: 0.8149
#
# Epoch 00070: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 71/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6344 - my_iou_metric_2: 0.9017 - val_loss: 0.2633 - val_my_iou_metric_2: 0.7842
#
# Epoch 00071: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 72/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5776 - my_iou_metric_2: 0.8890 - val_loss: 0.4954 - val_my_iou_metric_2: 0.7630
#
# Epoch 00072: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 73/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5783 - my_iou_metric_2: 0.8920 - val_loss: 0.1831 - val_my_iou_metric_2: 0.7907
#
# Epoch 00073: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 74/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5820 - my_iou_metric_2: 0.8888 - val_loss: 0.2878 - val_my_iou_metric_2: 0.7767
#
# Epoch 00074: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 75/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5975 - my_iou_metric_2: 0.8943 - val_loss: 0.1682 - val_my_iou_metric_2: 0.7959
#
# Epoch 00075: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 76/400
# 51/50 [==============================] - 81s 2s/step - loss: -0.5879 - my_iou_metric_2: 0.8910 - val_loss: 0.0908 - val_my_iou_metric_2: 0.7994
#
# Epoch 00076: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 77/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.5894 - my_iou_metric_2: 0.8923 - val_loss: 0.3897 - val_my_iou_metric_2: 0.7615
#
# Epoch 00077: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 78/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6300 - my_iou_metric_2: 0.9010 - val_loss: 0.2716 - val_my_iou_metric_2: 0.7872
#
# Epoch 00078: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 79/400
# 51/50 [==============================] - 81s 2s/step - loss: -0.6270 - my_iou_metric_2: 0.9027 - val_loss: 0.2927 - val_my_iou_metric_2: 0.7441
#
# Epoch 00079: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 80/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6277 - my_iou_metric_2: 0.9011 - val_loss: 0.1271 - val_my_iou_metric_2: 0.7940
#
# Epoch 00080: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 81/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6060 - my_iou_metric_2: 0.8978 - val_loss: 0.1969 - val_my_iou_metric_2: 0.7905
#
# Epoch 00081: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 82/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6256 - my_iou_metric_2: 0.8993 - val_loss: 0.0978 - val_my_iou_metric_2: 0.7886
#
# Epoch 00082: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 83/400
# 51/50 [==============================] - 82s 2s/step - loss: -0.6432 - my_iou_metric_2: 0.9053 - val_loss: 0.1324 - val_my_iou_metric_2: 0.7930
#
# Epoch 00083: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 84/400
# 51/50 [==============================] - 81s 2s/step - loss: -0.6375 - my_iou_metric_2: 0.9017 - val_loss: 0.2698 - val_my_iou_metric_2: 0.7749
#
# Epoch 00084: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 85/400
# 51/50 [==============================] - 81s 2s/step - loss: -0.6341 - my_iou_metric_2: 0.9013 - val_loss: 0.1382 - val_my_iou_metric_2: 0.7919
#
# Epoch 00085: val_my_iou_metric_2 did not improve from 0.81521
# Epoch 00085: early stopping
# [-11.51291546  -3.87081317  -3.15685969  -2.7299723   -2.42035452
#   -2.17476509  -1.96947293  -1.79180614  -1.63418879  -1.49172293
#   -1.3610532   -1.23977529  -1.12610286  -1.018668    -0.91639573
#   -0.81842178  -0.7240367   -0.63264686  -0.54374629  -0.45689595
#   -0.37170802  -0.28783374  -0.20495362  -0.12276948  -0.04099758
#    0.04063743   0.12240813   0.20458984   0.28746624   0.37133546
#    0.45651685   0.54335904   0.63224965   0.72362745   0.81799809
#    0.91595476   1.0182063    1.12561621   1.23925838   1.36049918
#    1.49112277   1.6335301    1.79107131   1.96863562   2.17378323
#    2.41915463   2.72840758   3.15456358   3.86632265   9.21024037]
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# ious:  [0.1310388  0.73642053 0.76733417 0.78235294 0.78973717 0.79549437
#  0.80125156 0.80175219 0.80438048 0.80763454 0.80963705 0.81163955
#  0.81138924 0.81239049 0.81301627 0.81476846 0.81501877 0.81501877
#  0.81501877 0.81602003 0.81602003 0.81739675 0.81727159 0.81727159
#  0.81727159 0.81639549 0.81664581 0.81589487 0.81501877 0.81439299
#  0.81389237 0.81401752 0.8126408  0.81339174 0.81301627 0.81214018
#  0.81076345 0.80938673 0.8097622  0.80838548 0.80650814 0.80450563
#  0.80062578 0.79649562 0.79048811 0.78222778 0.77546934 0.7649562
#  0.74030038 0.48335419]
# threshold_best[3]: -0.28783374076181156
# iou_best:  0.8173967459324155
#
# Fold 4
# ../models/keras_unet_resnet_42_f5_4_v31.model
# (3204, 101, 101, 1) (3204, 101, 101, 1) (796, 101, 101, 1)
# (3204, 101, 101, 1) (3204, 101, 101, 1) (796, 101, 101, 1)
# new validation size: (1592, 101, 101, 1) (1592, 101, 101, 1)
# Epoch 1/400
# (128, 101, 101, 1)
# 51/50 [==============================] - 63s 1s/step - loss: 0.4493 - my_iou_metric: 0.3209 - val_loss: 6.3996 - val_my_iou_metric: 0.1302
#
# Epoch 00001: val_my_iou_metric improved from -inf to 0.13021, saving model to ../models/keras_unet_resnet_42_f5_4_v31.model
# Epoch 2/400
# 51/50 [==============================] - 28s 547ms/step - loss: 0.3603 - my_iou_metric: 0.5014 - val_loss: 0.5674 - val_my_iou_metric: 0.3887
#
# Epoch 00002: val_my_iou_metric improved from 0.13021 to 0.38869, saving model to ../models/keras_unet_resnet_42_f5_4_v31.model
# Epoch 3/400
# 51/50 [==============================] - 28s 542ms/step - loss: 0.3276 - my_iou_metric: 0.5277 - val_loss: 0.4533 - val_my_iou_metric: 0.4782
#
# Epoch 00003: val_my_iou_metric improved from 0.38869 to 0.47820, saving model to ../models/keras_unet_resnet_42_f5_4_v31.model
# Epoch 4/400
# 51/50 [==============================] - 28s 542ms/step - loss: 0.3429 - my_iou_metric: 0.5198 - val_loss: 0.7481 - val_my_iou_metric: 0.3756
#
# Epoch 00004: val_my_iou_metric did not improve from 0.47820
# Epoch 5/400
# 51/50 [==============================] - 28s 551ms/step - loss: 0.3127 - my_iou_metric: 0.5272 - val_loss: 1.0721 - val_my_iou_metric: 0.3732
#
# Epoch 00005: val_my_iou_metric did not improve from 0.47820
# Epoch 6/400
# 51/50 [==============================] - 28s 543ms/step - loss: 0.2967 - my_iou_metric: 0.5742 - val_loss: 0.6622 - val_my_iou_metric: 0.2908
#
# Epoch 00006: val_my_iou_metric did not improve from 0.47820
# Epoch 7/400
# 51/50 [==============================] - 28s 543ms/step - loss: 0.2876 - my_iou_metric: 0.5748 - val_loss: 0.5597 - val_my_iou_metric: 0.3844
#
# Epoch 00007: val_my_iou_metric did not improve from 0.47820
# Epoch 8/400
# 51/50 [==============================] - 28s 547ms/step - loss: 0.3077 - my_iou_metric: 0.5546 - val_loss: 1.2703 - val_my_iou_metric: 0.3901
#
# Epoch 00008: val_my_iou_metric did not improve from 0.47820
# Epoch 9/400
# 51/50 [==============================] - 28s 543ms/step - loss: 0.2727 - my_iou_metric: 0.5766 - val_loss: 0.3811 - val_my_iou_metric: 0.4168
#
# Epoch 00009: val_my_iou_metric did not improve from 0.47820
# Epoch 10/400
# 51/50 [==============================] - 28s 543ms/step - loss: 0.2591 - my_iou_metric: 0.6018 - val_loss: 2.9668 - val_my_iou_metric: 0.2957
#
# Epoch 00010: val_my_iou_metric did not improve from 0.47820
# Epoch 11/400
# 51/50 [==============================] - 28s 544ms/step - loss: 0.2285 - my_iou_metric: 0.6027 - val_loss: 0.3784 - val_my_iou_metric: 0.4530
#
# Epoch 00011: val_my_iou_metric did not improve from 0.47820
# Epoch 12/400
# 51/50 [==============================] - 28s 546ms/step - loss: 0.2278 - my_iou_metric: 0.5903 - val_loss: 0.4249 - val_my_iou_metric: 0.3894
#
# Epoch 00012: val_my_iou_metric did not improve from 0.47820
# Epoch 13/400
# 51/50 [==============================] - 28s 544ms/step - loss: 0.2223 - my_iou_metric: 0.6054 - val_loss: 0.2489 - val_my_iou_metric: 0.5789
#
# Epoch 00013: val_my_iou_metric improved from 0.47820 to 0.57889, saving model to ../models/keras_unet_resnet_42_f5_4_v31.model
# Epoch 14/400
# 51/50 [==============================] - 28s 544ms/step - loss: 0.2090 - my_iou_metric: 0.6356 - val_loss: 0.3060 - val_my_iou_metric: 0.5513
#
# Epoch 00014: val_my_iou_metric did not improve from 0.57889
# Epoch 15/400
# 51/50 [==============================] - 28s 543ms/step - loss: 0.2000 - my_iou_metric: 0.6455 - val_loss: 0.3188 - val_my_iou_metric: 0.6145
#
# Epoch 00015: val_my_iou_metric improved from 0.57889 to 0.61451, saving model to ../models/keras_unet_resnet_42_f5_4_v31.model
# Epoch 16/400
# 51/50 [==============================] - 28s 549ms/step - loss: 0.2032 - my_iou_metric: 0.6385 - val_loss: 0.4748 - val_my_iou_metric: 0.4229
#
# Epoch 00016: val_my_iou_metric did not improve from 0.61451
# Epoch 17/400
# 51/50 [==============================] - 28s 545ms/step - loss: 0.2005 - my_iou_metric: 0.6488 - val_loss: 0.3200 - val_my_iou_metric: 0.5052

# %%
pred_dict = {idx: rle_encode(np.round(oof_test[i])) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}

# %%
sub = pd.DataFrame.from_dict(pred_dict, orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
#sub.to_csv('../submissions/submission_oof_{0}_unet_resnet_v{1}.csv'.format(FOLDS, VERSION))

# %%
val_iou = iou_metric_batch(y_train, oof_train)
val_iou

# %%
str(np.round(val_iou, 3))[2:]

# %%
#0.8114000000000001 0.813625 0.8077750000000001

# %%
gc.collect()
pickle.dump(oof_train, open('../pickle/train_oof_{0}_unet_v{1}'.format(FOLDS, VERSION), 'wb+'), protocol=4)
pickle.dump(oof_test, open('../pickle/test_oof_{0}_unet_v{1}'.format(FOLDS, VERSION), 'wb+'), protocol=4)
#pickle.dump(oof_test_skf, open('../pickle/test_skf_{0}_oof_unet_v{1}'.format(FOLDS, VERSION), 'wb+'), protocol=4)
pickle.dump(threshold_best, open('../pickle/threshold_best_{0}_unet_v{1}'.format(FOLDS, VERSION), 'wb+'), protocol=4)

#for i in oof_test_skf:
    
#pickle.dump(oof_test_skf, open('../pickle/test_skf_{0}_oof_unet_v{1}'.format(FOLDS, VERSION), 'wb+'), protocol=4)

# %%
valid_dict = {idx: rle_encode(np.round(oof_train[i])) for i, idx in enumerate(tqdm_notebook(train_df.index.values))}
val = pd.DataFrame.from_dict(valid_dict, orient='index')
val.index.names = ['id']
val.columns = ['rle_mask']
val.to_csv('../submissions/oof/train_oof_{0}_unet_resnet_v{1}_ls{2}.csv'.format(FOLDS, VERSION, str(np.round(val_iou, 3))[2:]))
sub.to_csv('../submissions/oof/test_oof_{0}_unet_resnet_v{1}_ls{2}.csv'.format(FOLDS, VERSION, str(np.round(val_iou, 3))[2:]))
